# %%
# !pip install BeautifulSoup
# !pip install requests

# %%
from bs4 import BeautifulSoup as bs 
import requests   # importing requests module to open a URL

# %%
urlopen = requests.get('https://www.nemlig.com/oksemoerbrad-5055713').text

# %%
soup = bs(urlopen,'html.parser')

# %%
print(soup)
# Out:
# <!DOCTYPE html>
#
# <!--[if IEMobile 7 ]> <html dir="ltr" lang="da" class="no-js iem7"> <![endif]-->
# <!--[if lt IE 7 ]> <html dir="ltr" lang="da" class="no-js ie6"> <![endif]-->
# <!--[if IE 7 ]> <html dir="ltr" lang="da" class="no-js ie7"> <![endif]-->
# <!--[if IE 8 ]> <html dir="ltr" lang="da" class="no-js ie8"> <![endif]-->
# <!--[if IE 9 ]> <html dir="ltr" lang="da" class="no-js ie9"> <![endif]-->
# <!--[if (gte IE 9)|(gt IEMobile 7)|!(IEMobile)|!(IE)]><!-->
# <html class="no-js" dir="ltr" lang="da" ng-controller="AppCtrl" states-manager="" xml:lang="da">
# <!--<![endif]-->
# <!--NOSONAR-->
# <head>
# <script data-culture="DA" id="CookieConsent" src="https://policy.app.cookieinformation.com/uc.js" type="text/javascript"></script>
# <script>
#         (function (i, s, o, g, r, a, m) {
#         i['GoogleAnalyticsObject'] = r; i[r] = i[r] || function () {
#             (i[r].q = i[r].q || []).push(arguments)
#         }, i[r].l = 1 * new Date(); a = s.createElement(o),
# ...
